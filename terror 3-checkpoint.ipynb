# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('group 3.csv')
print(dataset.shape)
# Out:
# (5110, 12)

# %%
dataset.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
dataset['bmi'].fillna(value=int(dataset['bmi'].median(skipna=True)),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False)

# %%
dataset['gender'].value_counts().plot.bar()
(dataset['gender'].value_counts()/len(dataset['gender'])).plot.bar()
plt.show()

# %%
dataset['ever_married'].value_counts().plot.bar()
(dataset['ever_married'].value_counts()/len(dataset['ever_married'])).plot.bar()
plt.show()

# %%
dataset['work_type'].value_counts().plot.bar()
(dataset['work_type'].value_counts()/len(dataset['work_type'])).plot.bar()
plt.show()

# %%
dataset['Residence_type'].value_counts().plot.bar()
(dataset['Residence_type'].value_counts()/len(dataset['Residence_type'])).plot.bar()
plt.show()

# %%
dataset['smoking_status'].value_counts().plot.bar()
(dataset['smoking_status'].value_counts()/len(dataset['smoking_status'])).plot.bar()
plt.show()

# %%
dataset['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
dataset['gender'].value_counts()/dataset.shape[0]
# Out:
# Female    0.585910
# Male      0.413894
# Other     0.000196
# Name: gender, dtype: float64

# %%
dataset.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.858102     0.048728
# std            45.283560     7.699976     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.000000     0.000000
# ...

# %%
plt.hist(dataset['id'])
plt.show()
print("skewness:%f" % dataset['id'].skew())
print("kurtosis:%f" % dataset['id'].kurt())
# Out:
# skewness:-0.019913
# kurtosis:-1.212368

# %%
plt.hist(dataset['age'])
plt.show()
print("skewness:%f" % dataset['age'].skew())
print("kurtosis:%f" % dataset['age'].kurt())
# Out:
# skewness:-0.137059
# kurtosis:-0.991010

# %%
plt.hist(dataset['hypertension'])
plt.show()
print("skewness:%f" % dataset['hypertension'].skew())
print("kurtosis:%f" % dataset['hypertension'].kurt())
# Out:
# skewness:2.715392
# kurtosis:5.375456

# %%
plt.hist(dataset['heart_disease'])
plt.show()
print("skewness:%f" % dataset['heart_disease'].skew())
print("kurtosis:%f" % dataset['heart_disease'].kurt())
# Out:
# skewness:3.947244
# kurtosis:13.586052

# %%
plt.hist(dataset['avg_glucose_level'])
plt.show()
print("skewness:%f" % dataset['avg_glucose_level'].skew())
print("kurtosis:%f" % dataset['avg_glucose_level'].kurt())
# Out:
# skewness:1.572284
# kurtosis:1.680479

# %%
plt.hist(dataset['bmi'])
plt.show()
print("skewness:%f" % dataset['bmi'].skew())
print("kurtosis:%f" % dataset['bmi'].kurt())
# Out:
# skewness:1.089528
# kurtosis:3.636108

# %%
plt.hist(dataset['stroke'])
plt.show()
print("skewness:%f" % dataset['stroke'].skew())
print("kurtosis:%f" % dataset['stroke'].kurt())
# Out:
# skewness:4.193284
# kurtosis:15.589736

# %%
plt.boxplot(dataset['id'])
plt.show()

# %%
plt.boxplot(dataset['age'])
plt.show()

# %%
import numpy
dataset1 = dataset[['id','age','hypertension','heart_disease','avg_glucose_level','bmi','stroke']]
names=['id','age','hypertension','heart_disease','avg_glucose_level','bmi','stroke']
correlations=dataset1.corr()
fig=plt.figure()
ax=fig.add_subplot(111)
cax=ax.matshow(dataset.corr(),cmap='cool',vmin=-1,vmax=1,interpolation='none')
fig.colorbar(cax)
ticks=numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(dataset)
ax.set_yticklabels(dataset)
plt.show()

# %%
from numpy.random import seed
from numpy.random import randn
from scipy.stats import ttest_ind
seed(1)csv
data1=pd.read_csv("data1.csv")
data1.shape
data2=pd.read_csv("daata2.csv")
data2.shape
stat,p=ttest_ind(data1,data2)
print(stat)
print(p)
data1.mwan()
data2.mean()
# Out:
#   File "<ipython-input-34-1e1eccd7bc47>", line 4
#     seed(1)csv,
#            ^
# SyntaxError: invalid syntax

# %%
#creating independent and dependent variables
x=dataset.iloc[:,2:11]
y=dataset.iloc[:,11]

# %%
x
# Out:
#        age  hypertension  heart_disease ever_married      work_type  \
# 0     67.0             0              1          Yes        Private
# 1     61.0             0              0          Yes  Self-employed
# 2     80.0             0              1          Yes        Private
# 3     49.0             0              0          Yes        Private
# 4     79.0             1              0          Yes  Self-employed
# ...    ...           ...            ...          ...            ...
# 5105  80.0             1              0          Yes        Private
# 5106  81.0             0              0          Yes  Self-employed
# 5107  35.0             0              0          Yes  Self-employed
# 5108  51.0             0              0          Yes        Private
# 5109  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status
# 0             Urban             228.69  36.6  formerly smoked
# ...

# %%
# splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
# feature scaling
from sklearn.preprocessing import srandardscaler
sc= standardscaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-dc7a8419f401> in <module>
#       1 # feature scaling
# ----> 2 from sklearn.preprocessing import srandardscaler
#       3 sc= standardscaler()
#       4 x_train=sc.fit_transform(x_train)
#       5 x_test=sc.transform
#
# ImportError: cannot import name 'srandardscaler' from 'sklearn.preprocessing' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)
